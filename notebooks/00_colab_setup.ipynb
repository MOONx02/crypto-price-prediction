# %% [markdown]
# # Colab setup — run this first
#
# Run the two cells below once per session. Then open **01_data_and_baselines.ipynb**, **02_lag_model.ipynb**, or **03_lstm.ipynb** from the file browser (📁 sidebar → `crypto-price-prediction/notebooks/`) and run them.
#
# **Optional:** Runtime → Change runtime type → **GPU** to speed up the LSTM (notebook 03).

# %%
# Clone repo (uses GITHUB_TOKEN from Colab Secrets if your repo is private)
try:
  from google.colab import userdata
  token = userdata.get('GITHUB_TOKEN')
  repo = "https://" + token + "@github.com/MOONx02/crypto-price-prediction.git"
except Exception:
  repo = "https://github.com/MOONx02/crypto-price-prediction.git"
import subprocess
subprocess.run(["git", "clone", "-q", repo], check=True)
# %cd crypto-price-prediction

# %%
# Install dependencies
# !pip install -q -r requirements.txt
print('Done. Open 01_data_and_baselines.ipynb (or 02, 03) from the file browser.')
